# %% [markdown]
# # Some resources to help you along the way
#
# - Resources from a workshop on **Visual Document Retrieval** can be found [here](https://github.com/harpreetsahota204/visual_document_retrieval_in_fiftyone_talk)
#
# - Resourced and code samples from the Document Visual AI workshop can be found [here](https://github.com/harpreetsahota204/document_visual_ai_with_fiftyone_workshop)

# %% [markdown]
# ## Load the dataset

# %%
#your code here

# %% [markdown]
# #### Take a random sample
#
# If you want to just work with a small subset of your data, create a random sample of ~1000 samples.

# %%
#your code here

# %% [markdown]
# ### Launch the App and explore the dataset

# %%
# your code here

# %% [markdown]
# ### Compute embeddings for the images
#
# Some models you may want to consider...
#
# **From the FiftyOne Model Zoo:**
#
# - [CLIP](https://docs.voxel51.com/model_zoo/models/clip_vit_base32_torch.html)
#
# - [DinoV2](https://docs.voxel51.com/model_zoo/models/dinov2_vitb14_reg_torch.html)
#
# - [ResNeXt](https://docs.voxel51.com/model_zoo/models/resnext101_32x8d_imagenet_torch.html)
#
# **Remote Source Zoo Models:**
#
#
# - [NVIDIA CRADIOv4](https://github.com/harpreetsahota204/CRADIOv4)
#
# - [NVIDIA CRADIOv3](https://github.com/harpreetsahota204/NVLabs_CRADIOV3)
#
# - [Qwen3-VL Embeddings](https://github.com/harpreetsahota204/qwen3vl_embeddings)

# %%
# your code here

# %% [markdown]
# ### Use zero-shot classification if your model is capable of it

# %%
# your code here

# %% [markdown]
# ### Compute Visualization
#
# Now that you have your embeddings, let's visualize them in the app

# %%
# your code here

# %% [markdown]
# ### Build a similarity index
#
# Let's build a similarity index so we can sort by similarity, or by natural language (if your chosen model supports it).

# %%
# your code here

# %% [markdown]
# ## Explore the embeddings panel
#
# Let's now turn back to the App and explore the visualization in the [Embeddings Panel](https://docs.voxel51.com/user_guide/app.html#embeddings-panel).
#
# We want to find images which have handwritten text on them and discard the rest.
#
# In the App, tag samples as either `keep` or `discard`. Or, if you find it easier just tag the ones you want to keep.

# %% [markdown]
# ### Create a View with just those Samples tagged as `keep`
#
# Check out these resources if you need a refresher:
#
# - [Views Cheat Sheet](https://docs.voxel51.com/cheat_sheets/views_cheat_sheet.html)
#
# - [Filtering Cheat Sheet](https://docs.voxel51.com/cheat_sheets/filtering_cheat_sheet.html)

# %%
# your code here

# %% [markdown]
# ### Use a VLM for OCR
#
# Take care to note the requirements for libraries from the model card
#
# - [Miner-U 2.5](https://github.com/harpreetsahota204/mineru_2_5)
#
# - [Qwen3.5-VL](https://github.com/harpreetsahota204/qwen3_5_vl)
#
# - [Moondream3](https://github.com/harpreetsahota204/moondream3)
#
# - [Gemma 4](https://github.com/Burhan-Q/gemma4)
#
# - [DeepSeek-OCR](https://github.com/harpreetsahota204/deepseek_ocr)
#
# - [Kosmos2.5](https://github.com/harpreetsahota204/kosmos2_5)
#
# - [PaliGemma2](https://github.com/harpreetsahota204/paligemma2)
#
# You can look for other models [here](https://github.com/voxel51/fiftyone-plugins?tab=readme-ov-file#community-plugins), including models for simple VQA.
#
# ### Alternatively...
#
# You can also use a model from the:
#
# - [FiftyOne Model Zoo](https://docs.voxel51.com/model_zoo/index.html)
#
# - [With the FiftyOne + Ultralytics Integration](https://docs.voxel51.com/integrations/ultralytics.html)
#
# - Or by using any model you want, iterating over Samples, and adding the results back to the Dataset as [a FiftyOne Label type](https://docs.voxel51.com/user_guide/using_datasets.html#labels)

# %%
# your code here

# %% [markdown]
# ### Construct the prompt for the model
#
# If your model requires an operation to be set or a prompt, you can construct it here

# %% [markdown]
# ### Apply the model to your Dataset

# %% [markdown]
# ### Create a patches view

# %% [markdown]
# ### Create patch embeddings
